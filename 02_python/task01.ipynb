# %%
name = "大島圭貴"
age = 36

print("はじめまして、 ", name, "と申します。")
print("年齢は", age, "歳です。来年は", age + 1, "歳になります。")
print("よろしくお願いします。")
# Out:
# はじめまして、  大島圭貴 と申します。
# 年齢は 36 歳です。来年は 37 歳になります。
# よろしくお願いします。
