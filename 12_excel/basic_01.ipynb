# %%
# ワークフロー化
print("処理を開始します。")

# 1. Excelファイルを読み込む
df = pd.read_excel('サンプルデータ.xlsx', sheet_name='売上データ')

# 2. データをLLM用にテキスト形式に変換
sales_data_text = df.astype(str)
prompt_text = f"売上データ:\n{sales_data_text}\nこの売上データの傾向を分析してください。"

# 3. OpenAI APIの呼び出し
# 役割を設定
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"
# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# 4. 分析結果をデータフレームに変換
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=['結果'])

# 5. 結果をExcelファイルに保存
df_out.to_excel("売上データ分析結果.xlsx", index=False)

print("Excelファイルに分析結果を保存しました。")
# Out:
# 処理を開始します。
# Excelファイルに分析結果を保存しました。

# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd

# 環境変数の取得
load_dotenv()

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"


# 1. Excelファイルを読み込む
df = pd.read_excel('./サンプルデータ.xlsx', sheet_name='売上データ')
# データフレームを表示して確認
df.head()

# 2. データをLLM用にテキスト形式に変換
# データフレーム全体を文字列に変換
sales_data_text = df.astype(str)
prompt_text = f"売上データ:\n{sales_data_text}\nこの売上データの傾向を分析してください。"
# 表示して確認
print(prompt_text)

# 3. OpenAI APIの呼び出し

# 役割を設定
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# LLMからの回答を表示
print(response.choices[0].message.content.strip())


# 4. 分析結果をデータフレームに変換
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=['結果'])
print(df_out)

# 5. 結果をExcelファイルに保存
df_out.to_excel("売上データ分析結果.xlsx", index=False)
# Out:
# 売上データ:
#     カテゴリー 商品コード      商品名         売上日    単価   数量    原価
# 0      食品  1001      りんご  2023-01-01   200   50   120
# 1      食品  1002      バナナ  2023-01-01   150  100    80
# 2      食品  1003       牛乳  2023-01-02   180   80   100
# 3      衣服  2001     Tシャツ  2023-01-02  1500   20   800
# 4      衣服  2002     ジーンズ  2023-01-03  5000   10  2500
# ..    ...   ...      ...         ...   ...  ...   ...
# 235    衣服  2077   レインパンツ  2023-04-28  2000   18  1000
# 236    食品  1085      ザクロ  2023-04-29   600   40   300
# 237   日用品  3077    バスブラシ  2023-04-29   400   60   200
# 238    衣服  2078  レインシューズ  2023-04-30  2500   15  1250
# 239    食品  1086    ココナッツ  2023-04-30   300   80   150
#
# [240 rows x 7 columns]
# この売上データの傾向を分析してください。
# この売上データを分析することで、いくつかの興味深い傾向やインサイトを引き出すことができます。以下に、主な傾向や分析を示します。
#
# ### 1. カテゴリー別の売上分析
# - **食品、衣服、日用品**に分かれており、各カテゴリーの売上を比較できます。例えば、食品が多くの商品コードを持っている場合、日々の消費頻度が高いことを示唆します。
# - 売上金額や数量を合算し、どのカテゴリーが最も収益を挙げているかを調査します。
#
# ### 2. 売上の時系列分析
# - 売上日を基に、時間の経過に伴う売上のトレンドを確認します。特定の日や週に売上が急増または減少する場合、その理由を探ることができます（例：プロモーション、季節要因）。
# - 時間軸での移動平均を利用して、トレンドを滑らかにし、より長期的な傾向を確認します。
#
# ### 3. 売上単価と数量の関係
# - 商品による売上単価を分析することにより、高単価商品と低単価商品の販売パターンを把握できます。特に、数量が多く売れる低価格の商品と、少量でも高利益が見込める高価格の商品がどのようにバランスを取っているかを探ります。
#
# ### 4. 利益率の分析
# - **利益率**（売上 - 原価）を計算し、各商品のパフォーマンスを評価します。特に、高い利益率の商品を特定することで、マーケティング戦略を強化できます。
# - 利益率が高い商品に対しては、プロモーションやさらに高い売上を目指すための戦略（金額割引やセット販売など）を検討します。
#
# ### 5. 商品コード別のパフォーマンス
# - どの具体的な商品コードが最も売上を支えているのか、また新たに追加した商品が売上にどのように寄与しているかをチェックします。特定の商品が期待通りのパフォーマンスを発揮していない場合、商品の再評価や改善策を講じる必要があります。
#
# ### 6. 季節的なトレンド
# - 特定の商品やカテゴリーが季節によって異なる売上を示す場合、この情報を基に新たな売上機会を発見することができるかもしれません。例えば、特定の食品は夏に人気が高まり、冬には衣服が売れる傾向があるかもしれません。
#
# ### 提案
# - 売上データを視覚化し、ダッシュボード形式でパフォーマンスを監視することで、リアルタイムの意思決定に貢献します。
# - 顧客からのフィードバックを取り入れ、商品開発やマーケティング戦略を調整することで、より効率的に売上を向上させることが可能です。
#
# この分析を通じて、売上の最大化に向けた具体的な施策を構築することができます。データのトレンドやパターンを継続的に監視することで、より効果的に戦略を調整することが可能です。
#                                                    結果
# 0   この売上データを分析することで、いくつかの興味深い傾向やインサイトを引き出すことができます。...
# 1
# 2                                  ### 1. カテゴリー別の売上分析
# 3   - **食品、衣服、日用品**に分かれており、各カテゴリーの売上を比較できます。例えば、食品...
# 4            - 売上金額や数量を合算し、どのカテゴリーが最も収益を挙げているかを調査します。
# 5
# 6                                     ### 2. 売上の時系列分析
# 7   - 売上日を基に、時間の経過に伴う売上のトレンドを確認します。特定の日や週に売上が急増または...
# 8         - 時間軸での移動平均を利用して、トレンドを滑らかにし、より長期的な傾向を確認します。
# 9
# 10                                  ### 3. 売上単価と数量の関係
# 11  - 商品による売上単価を分析することにより、高単価商品と低単価商品の販売パターンを把握できま...
# 12
# 13                                      ### 4. 利益率の分析
# 14  - **利益率**（売上 - 原価）を計算し、各商品のパフォーマンスを評価します。特に、高い...
# 15  - 利益率が高い商品に対しては、プロモーションやさらに高い売上を目指すための戦略（金額割引や...
# 16
# 17                              ### 5. 商品コード別のパフォーマンス
# 18  - どの具体的な商品コードが最も売上を支えているのか、また新たに追加した商品が売上にどのよう...
# 19
# 20                                    ### 6. 季節的なトレンド
# 21  - 特定の商品やカテゴリーが季節によって異なる売上を示す場合、この情報を基に新たな売上機会を...
# 22
# 23                                             ### 提案
# 24  - 売上データを視覚化し、ダッシュボード形式でパフォーマンスを監視することで、リアルタイムの...
# 25  - 顧客からのフィードバックを取り入れ、商品開発やマーケティング戦略を調整することで、より効...
# 26
# 27  この分析を通じて、売上の最大化に向けた具体的な施策を構築することができます。データのトレンド...
