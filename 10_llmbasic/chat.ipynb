# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# {'_request_id': 'req_c3c03e51b2544e13becf26d408c53583',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に使うためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。\n\n1. **目的を明確にする**: 何を達成したいのかを明確にすることで、適切な質問やプロンプトを作成できます。\n\n2. **具体的なプロンプトを使用する**: モデルに具体的で詳細な指示を与えることで、より有用で正確な回答を得やすくなります。\n\n3. **コンテキストを提供する**: 必要な背景情報や文脈を与えることで、モデルの理解を深め、期待する回答の質を向上させることができます。\n\n4. **試行錯誤をする**: 最初のプロンプトで理想的な回答が得られない場合は、文を修正したり、異なるアプローチを試したりすることが重要です。\n\n5. **モデルの限界を理解する**: 言語モデルは知識の限界があり、常に正確な情報を提供できるわけではありません。特に、最新の情報や特定の専門的な知識については注意が必要です。\n\n6. **レスポンスを評価する**: 得られた回答の正確性や有用性について批判的に評価し、必要に応じて別の観点から再度質問することが大切です。\n\n7. **倫理的考慮**: モデルを使用する際には、倫理的な配慮も重要です。不適切な内容や偏見を助長しないように心がけましょう。\n\nこれらのポイントを考慮しながら言語モデルを活用することで、より効果的な結果が得られるでしょう。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))],
#  'created': 1771402940,
#  'id': 'chatcmpl-DAX76IoWqSqXnp3jyxRmmRgrWEIDg',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_373a14eb6f',
#  'usage': CompletionUsage(completion_tokens=416, prompt_tokens=18, total_tokens=434, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}
# 言語モデルを効果的に使うためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。
#
# 1. **目的を明確にする**: 何を達成したいのかを明確にすることで、適切な質問やプロンプトを作成できます。
#
# 2. **具体的なプロンプトを使用する**: モデルに具体的で詳細な指示を与えることで、より有用で正確な回答を得やすくなります。
#
# 3. **コンテキストを提供する**: 必要な背景情報や文脈を与えることで、モデルの理解を深め、期待する回答の質を向上させることができます。
#
# 4. **試行錯誤をする**: 最初のプロンプトで理想的な回答が得られない場合は、文を修正したり、異なるアプローチを試したりすることが重要です。
#
# 5. **モデルの限界を理解する**: 言語モデルは知識の限界があり、常に正確な情報を提供できるわけではありません。特に、最新の情報や特定の専門的な知識については注意が必要です。
#
# 6. **レスポンスを評価する**: 得られた回答の正確性や有用性について批判的に評価し、必要に応じて別の観点から再度質問することが大切です。
#
# 7. **倫理的考慮**: モデルを使用する際には、倫理的な配慮も重要です。不適切な内容や偏見を助長しないように心がけましょう。
#
# これらのポイントを考慮しながら言語モデルを活用することで、より効果的な結果が得られるでしょう。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=0.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる祭りは、地域の伝統や文化を体験できる貴重な機会です。例えば、京都の祇園祭や青森のねぶた祭り
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# 日本は古くからの伝統と現代文化が共存しています。茶道、花道、武道などの伝統芸能はもちろん、祭りや神社仏閣も多く、四季折々の行事が楽しめます。
#
# ### 2. 美しい自然
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# 日本は古くからの伝統と現代文化が共存しています。茶道、花道、武道などの伝統芸能はもちろん、祭りや神社仏閣も多く、四季折々の行事が楽しめます。
#
# ### 2. 美しい自然

# %%
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# 日本の魅力は多岐にわたります。以下にいくつかのポイントを挙げて紹介します。
#
# 1. **豊かな自然**: 日本は多様な自然環境を持つ国で、四季の変化がはっきりしています。富士山や四国の山々、北海道の大自然、沖縄の美しい海など、さまざまな自然の美しさを楽しむこと
# --------------------
# もちろんです！日本は多様で魅力的な文化や自然が魅力の国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **伝統的な祭り**: いろいろな地域で行われる祭りは日本文化の魅力です。例えば、京都の祇園祭りや仙台の七夕祭りがあります。
# - **茶道**:
# --------------------
# もちろんです！日本の魅力は多岐にわたりますので、いくつかのポイントを紹介します。
#
# 1. **自然の美**:
#    - 日本は四季がはっきりしており、春は桜、夏は緑豊かな山々、秋は紅葉、冬は雪景色が楽しめます。特に、京都の紅葉や、北海道の雪景色は美しいです。
#
# 2.

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、最近どうですか？
# --------------------
# B:こんにちは！Aさん、最近どうですか？
# --------------------
# B:こんにちは！Aさん、最近どうしていますか？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に使用するためのポイントはいくつかあります。以下に主なポイントを挙げます：
#
# 1. **明確なプロンプト**: 言語モデルに入力するプロンプトは明確で具体的であることが重要です。質問や要求があいまいだと、モデルから返される答えもあいまいになりがちです。
#
# 2. **コンテキストの提供**: 複雑な質問やタスクの場合、関連するコンテキストや背景情報を提供することが役立ちます。これにより、モデルはより正確な回答を生成しやすくなります。
#
# 3. **反復的な対話**: モデルとの対話は一度で完結するわけではなく、反復的に行うことでより良い結果が得られることがあります。初回の回答に対するフィードバックを与えることで、次の応答を改善することができます。
#
# 4. **クリエイティブな利用**: 言語モデルは様々な用途に適しています。文章作成、アイデアのブレインストーミング、プログラミングの支援、学習材料の生成など、クリエイティブに活用することができます。
#
# 5. **限界の理解**: モデルは知識や事実に基づいて応答しますが、必ずしも正確な情報を提供するわけではありません。特に、最新の情報や特定の知識領域に関しては、結果を鵜呑みにせず、必ず確認することが大切です。
#
# 6. **フィードバックの提供**: モデルの応答に対してフィードバックを提供することで、次に何を期待できるかを明確に伝えることができます。これにより、より望ましい応答を得られる可能性が高まります。
#
# 7. **倫理的な使用**: 言語モデルを使用する際は、倫理的な観点を考慮することが重要です。誤情報の拡散や偏見の助長、プライバシーの侵害などを避けるために、責任を持って利用しましょう。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用できるようになるでしょう。
