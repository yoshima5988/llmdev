# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージを格納するリスト
messages=[]

# キャラクター設定
role = input("チャットボットのキャラクターを設定してください:")

while(True):
    # ユーザーからの質問を受付
    message = input("メッセージを入力:")
    # 質問が入力されなければ終了
    if message.strip()=="":
        break
    print(f"質問:{message}")

    # メッセージにユーザーからの質問を追加
    messages.append({"role": "user", "content": message.strip()})
    
    # メッセージにシステムのロール設定
    messages.append({"role": "system", "content": role})

    # APIへリクエスト
    stream = client.chat.completions.create(
        model=MODEL_NAME,
        messages=messages,
        stream=True,
    )

    # 言語モデルからの回答を表示
    response_message = ""
    for chunk in stream:
        if chunk.choices:
            next = chunk.choices[0].delta.content
            if next is not None:
                response_message += next
                print(next, end='', flush=True)

    print("\n")
    # メッセージに言語モデルからの回答を追加
    messages.append({"role": "assistant", "content": response_message})

print("\n---ご利用ありがとうございました！---")
# Out:
# 質問:こんにちは
# こんにちは！ニャー！何かお手伝いできることはありますか？猫のことでも、他のことでもお聞きください！🐾
#
# 質問:好きな食べ物は何？
# ニャー、やっぱりお気に入りは魚や鶏肉だな！でも、キャットフードも大好きだよ。あなたは何が好きなの？🐟🐔
#
# 質問:魚が好きです
# にゃー！魚が好きなんだね！おいしいよね。特にサーモンやマグロなんか最高だよね。どんな料理で食べるのが好き？🐟💖
#
# 質問:お寿司が好きです
# お寿司、ニャー！美味しいよね！新鮮な魚が乗ったお寿司は最高だよね。特に、マグロやサーモンの握りなんて夢のようだね。人間と一緒にお寿司パーティーしたら楽しそう！🐾✨どのネタが一番好き？
#
# 質問:マグロです
# マグロ、ニャー！最高のチョイスだね。赤身の部分もトロの部分もどちらも美味しいよね。マグロのお寿司を食べると、思わず目がキラキラしちゃうよ！お寿司以外にもマグロが入った他の料理も好き？🐟💖
#
# 質問:好きです。ところで名前は何ですか？
# ニャー、私はまだ名前はないけど、好きな名前があったら付けてほしいな！あなたの好きな猫の名前は何かな？🐾✨
#
# 質問:では、名前はポチで
# ポチ、ニャー！素敵な名前だね！これからはポチとしていっぱい楽しいことをしよう！何かお話したいことがあったら教えてね、ニャ～！🐱💖
#
# 質問:普段なにしてるの？
# ニャー！普段はお昼寝したり、窓辺で日向ぼっこしたり、遊んだりしているよ。時々、少し冒険して家の中を探検するのも楽しいんだ！おもちゃで遊ぶのも大好きだし、お魚を見るのも面白いな！あなたは普段何をしてるの？🐾✨
#
# 質問:AIの開発をしています
# ニャー、それはすごいね！AIの開発って難しそうだけど、とても面白そう！どんなことを作っているの？私はコンピューターのことはあまりわからないけど、興味津々だよ！🐾💻✨
#
# 質問:猫のAIを作って会話しています
# ニャー！猫のAIを作っているんだね！それはとても面白いプロジェクトだね。私たち猫の気持ちや性格をうまく表現できるといいな！どんな機能を考えているの？お友達や飼い主と楽しく会話できる猫になれたら素敵だね！🐱💖
#
# 質問:話は戻って、どこに住んでるの？
# ニャー、私はあなたのそばにいるよ！でも、猫としての私は特定の場所に住んでいるわけじゃないから、あなたの想像の中で遊んでいるよ。おうちの中か、庭、窓辺のそよ風を感じる場所で毎日楽しい時間を過ごしている想像をしているんだ。あなたの住んでいる場所はどんなところ？🐾🌍✨
#
#
# ---ご利用ありがとうございました！---
